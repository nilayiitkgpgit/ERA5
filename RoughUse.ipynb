# %% [markdown]
# # Seeing my study area=>

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. DEFINE COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 10, 50
plot_lat_min, plot_lat_max = 50, 90

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 72, 82
study_lat_min, study_lat_max = 26, 38

# ===============================
# 2. LOAD INDIA SHAPEFILE
# ===============================
# 👉 Change this path to where your India shapefile is stored
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. CREATE FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Set plot extent
ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. ADD INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="black",
    linewidth=1
)

# ===============================
# 5. CREATE BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot extent box (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    label="Plot extent"
)

# Study area box (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    label="Study area"
)

# ===============================
# 6. GRIDLINES & LABELS
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linewidth=0.5,
    color="gray",
    alpha=0.5,
    linestyle="--"
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 7. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. CORRECT COORDINATES (INDIA)
# ===============================

# ---- Plot domain (BIG BOX) ----
plot_lon_min, plot_lon_max = 68, 98
plot_lat_min, plot_lat_max = 6, 36

# ---- Study area (SMALL BOX) ----
study_lon_min, study_lon_max = 85, 89
study_lat_min, study_lat_max = 21, 25

# ===============================
# 2. LOAD INDIA SHAPEFILE
# ===============================
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="lightgray",
    edgecolor="black",
    linewidth=0.8
)

# ===============================
# 5. BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot domain (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2
)

# Study area (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2
)

# ===============================
# 6. GRIDLINES
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linestyle="--",
    linewidth=0.5,
    alpha=0.6
)
gl.top_labels = False
gl.right_labels = False

ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 50, 90
plot_lat_min, plot_lat_max = 10, 50

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 75, 77
study_lat_min, study_lat_max = 30, 34

# ===============================
# 2. INDIA SHAPEFILE
# ===============================
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="lightgray",
    edgecolor="black",
    linewidth=0.8,
    zorder=2
)

# ===============================
# 5. COASTLINES (CARTOPY)
# ===============================
ax.coastlines(
    resolution="10m",   # "110m", "50m", "10m"
    linewidth=1.0,
    zorder=3
)

# ===============================
# 6. BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot domain (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    zorder=4
)

# Study area (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    zorder=4
)

# ===============================
# 7. GRIDLINES
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linestyle="--",
    linewidth=0.5,
    alpha=0.6
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 8. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import cdsapi
import os
import xarray as xr
import glob

# =====================================================
# USER SETTINGS
# =====================================================

out_dir = "/home/nilay/SSD Data Downloads/ERA5_CLIM"
os.makedirs(out_dir, exist_ok=True)

final_file = os.path.join(out_dir, "ERA5_Climatology_1980_2025.nc")

years = range(1998, 1999)
months = ["10"]

# North, West, South, East
area = [50, 60, 0, 100]
#area = None

c = cdsapi.Client()

# =====================================================
# DOWNLOAD SINGLE LEVEL DATA
# =====================================================

single_files = []

for y in years:

    year_str = str(y)
    out_file = os.path.join(out_dir, f"ERA5_single_{year_str}.nc")

    single_files.append(out_file)

    if os.path.exists(out_file):
        print("✅ Skip single:", year_str)
        continue

    print("⬇ Downloading single level:", year_str)

    request = {
        "product_type": "reanalysis",
        "variable": [
            "total_precipitation",
            "vertical_integral_of_divergence_of_moisture_flux",
            "vertical_integral_of_eastward_water_vapour_flux",
            "vertical_integral_of_northward_water_vapour_flux"
        ],
        "year": year_str,
        "month": months,
        "day": [f"{d:02d}" for d in range(1, 32)],
        "daily_statistic": "daily_mean",
        "time_zone": "utc+00:00",
        "frequency": "1_hourly",
        "data_format": "netcdf",
        "area": area
    }

    c.retrieve(
        "derived-era5-single-levels-daily-statistics",
        request,
        out_file
    )

# =====================================================
# DOWNLOAD PRESSURE LEVEL DATA
# =====================================================

pl_files = []

for y in years:

    year_str = str(y)
    out_file = os.path.join(out_dir, f"ERA5_pl_{year_str}.nc")

    pl_files.append(out_file)

    if os.path.exists(out_file):
        print("✅ Skip pressure:", year_str)
        continue

    print("⬇ Downloading pressure level:", year_str)

    request = {
        "product_type": "reanalysis",
        "variable": [
            "geopotential",
            "u_component_of_wind",
            "v_component_of_wind"
        ],
        "pressure_level": "850",
        "year": year_str,
        "month": months,
        "day": [f"{d:02d}" for d in range(1, 32)],
        "daily_statistic": "daily_mean",
        "time_zone": "utc+00:00",
        "frequency": "1_hourly",
        "data_format": "netcdf",
        "area": area
    }

    c.retrieve(
        "derived-era5-pressure-levels-daily-statistics",
        request,
        out_file
    )

# =====================================================
# MERGE ALL FILES
# =====================================================

print("\n📦 Opening datasets...")

ds_single = xr.open_mfdataset(single_files, combine="by_coords")
ds_pl = xr.open_mfdataset(pl_files, combine="by_coords")

print("🔗 Merging datasets...")

ds = xr.merge([ds_single, ds_pl])

print("💾 Saving final file...")

ds.to_netcdf(final_file)

print("\n✅ DONE — Final merged file saved:")
print(final_file)
# Out:
# ✅ Skip single: 1998
# ⬇ Downloading pressure level: 1998
# 2026-02-24 13:28:01,284 INFO Request ID is da2a29e2-d031-49a0-b493-9dcfe58de0f4
# 2026-02-24 13:28:01,508 INFO status has been updated to accepted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 104
#      84     print("⬇ Downloading pressure level:", year_str)
#      86     request = {
#      87         "product_type": "reanalysis",
#      88         "variable": [
#    (...)    101         "area": area
#     102     }
# --> 104     c.retrieve(
#     105         "derived-era5-pressure-levels-daily-statistics",
#     106         request,
#     107         out_file
#     108     )
#     110 # =====================================================
#     111 # MERGE ALL FILES
#     112 # =====================================================
#     114 print("\n📦 Opening datasets...")
#
# ...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# ============================================
# USER INPUT
# ============================================

# Study region (EDIT THIS)
lat_min, lat_max = 20, 32
lon_min, lon_max = 70, 90

# Shapefile path (India boundary or basin)
shapefile_path = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# Map extent (bigger than box)
extent = [40, 120, 0, 50]   # [lon_min, lon_max, lat_min, lat_max]

# ============================================
# CREATE FIGURE
# ============================================

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# ============================================
# SET MAP EXTENT
# ============================================

ax.set_extent(extent, crs=ccrs.PlateCarree())

# ============================================
# ADD FEATURES
# ============================================

ax.coastlines(resolution='110m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# ============================================
# ADD SHAPEFILE
# ============================================

shape = shpreader.Reader(shapefile_path)
ax.add_geometries(
    shape.geometries(),
    crs=ccrs.PlateCarree(),
    facecolor='none',
    edgecolor='black',
    linewidth=1.5
)

# ============================================
# DRAW LAT-LON BOX
# ============================================

# Box corners
lons = [lon_min, lon_max, lon_max, lon_min, lon_min]
lats = [lat_min, lat_min, lat_max, lat_max, lat_min]

ax.plot(
    lons, lats,
    color='red',
    linewidth=2,
    transform=ccrs.PlateCarree(),
    label='Study Region'
)

# ============================================
# GRIDLINES
# ============================================

gl = ax.gridlines(draw_labels=True, linewidth=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# ============================================
# TITLE
# ============================================

plt.title("Study Region over India", fontsize=14)

plt.legend()
plt.show()

# %% [markdown]
# # Plotting nc file =>

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# ============================================
# USER INPUT
# ============================================

lat_min, lat_max = 20, 32
lon_min, lon_max = 70, 90

nc_file = r"D:\PHD 2025~\PHD\5.ERA5_1980-2025_12Months_DailyPrep_unzipped\ERA5_Land_Rainfall_2025.nc"

shapefile_path = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

extent = [40, 120, 0, 50]

# ============================================
# LOAD DATA
# ============================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

# ============================================
# SELECT VARIABLE
# ============================================

precip = ds['tp']

# ⚠️ IMPORTANT: Your dataset uses 'valid_time'
precip = precip.isel(valid_time=0)

# ============================================
# SUBSET REGION (DO THIS EARLY → FAST)
# ============================================

precip = precip.sel(
    latitude=slice(lat_max, lat_min),   # reverse
    longitude=slice(lon_min, lon_max)
)

# Fix latitude orientation
precip = precip.sortby('latitude')

lat = precip['latitude']
lon = precip['longitude']

# ============================================
# UNIT CONVERSION
# ============================================

precip = precip * 1000   # meters → mm

# ============================================
# CREATE FIGURE
# ============================================

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(extent, crs=ccrs.PlateCarree())

# ============================================
# PLOT PRECIPITATION
# ============================================

precip = ds['tp'].isel(valid_time=200) * 1000

precip = precip.sel(
    latitude=slice(lat_max, lat_min),
    longitude=slice(lon_min, lon_max)
).sortby('latitude')

precip = precip.where(precip > 1)

pcm = ax.pcolormesh(
    precip['longitude'],
    precip['latitude'],
    precip,
    cmap='Blues',
    vmin=0,
    vmax=20,
    transform=ccrs.PlateCarree()
)

# ============================================
# MAP FEATURES
# ============================================

ax.coastlines(resolution='110m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# ============================================
# SHAPEFILE
# ============================================

shape = shpreader.Reader(shapefile_path)
ax.add_geometries(
    shape.geometries(),
    crs=ccrs.PlateCarree(),
    facecolor='none',
    edgecolor='black',
    linewidth=1.5
)

# ============================================
# STUDY REGION BOX
# ============================================

lons = [lon_min, lon_max, lon_max, lon_min, lon_min]
lats = [lat_min, lat_min, lat_max, lat_max, lat_min]

ax.plot(
    lons, lats,
    color='red',
    linewidth=2,
    transform=ccrs.PlateCarree(),
    label='Study Region'
)

# ============================================
# GRIDLINES
# ============================================

gl = ax.gridlines(draw_labels=True, linewidth=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# ============================================
# TITLE
# ============================================

plt.title("ERA5 Daily Precipitation (mm)", fontsize=14)

plt.legend()
plt.show()
# Out:
# 📂 Loading dataset...

# %% [markdown]
# # Checking if it contains all the NaN values only

# %%
import xarray as xr
import numpy as np

# Load file
nc_file = r"D:\PHD 2025~\PHD\5.ERA5_1980-2025_12Months_DailyPrep_unzipped\ERA5_Land_Rainfall_1991.nc"
ds = xr.open_dataset(nc_file)

print("\n📂 DATASET SUMMARY:")
print(ds)

# ============================================
# CHECK VARIABLE
# ============================================

print("\n📊 VARIABLES:")
print(ds.data_vars)

# Select precipitation
precip = ds['tp']

# ============================================
# CHECK DIMENSIONS
# ============================================

print("\n📐 DIMENSIONS:")
print(precip.dims)

# ============================================
# CHECK TIME
# ============================================

print("\n⏱️ TIME VALUES:")
print(ds['valid_time'].values[:5])  # first 5 timesteps

# Select one timestep
precip_1 = precip.isel(valid_time=200)

# ============================================
# BASIC STATS
# ============================================

print("\n📈 STATISTICS (RAW):")
print("Min:", float(precip_1.min()))
print("Max:", float(precip_1.max()))
print("Mean:", float(precip_1.mean()))

# Convert to mm
precip_1_mm = precip_1 * 1000

print("\n📈 STATISTICS (mm):")
print("Min:", float(precip_1_mm.min()))
print("Max:", float(precip_1_mm.max()))
print("Mean:", float(precip_1_mm.mean()))

# ============================================
# CHECK FOR NaNs
# ============================================

print("\n❓ NaN CHECK:")
print("Total NaNs:", int(np.isnan(precip_1.values).sum()))

# ============================================
# CHECK REGION VALUES
# ============================================

precip_region = precip_1.sel(
    latitude=slice(32, 20),
    longitude=slice(70, 90)
)

print("\n📍 REGION STATS:")
print("Min:", float(precip_region.min()))
print("Max:", float(precip_region.max()))
print("Mean:", float(precip_region.mean()))

# ============================================
# PRINT SAMPLE GRID
# ============================================

print("\n🔍 SAMPLE VALUES:")
print(precip_region.values[0:5, 0:5])
# Out:
# 📂 DATASET SUMMARY:
# <xarray.Dataset> Size: 586MB
# Dimensions:     (valid_time: 365, latitude: 501, longitude: 801)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 3kB 1991-01-01 ... 1991-12-31
#     expver      (valid_time) <U4 6kB ...
#   * latitude    (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude   (longitude) float64 6kB 40.0 40.1 40.2 ... 119.8 119.9 120.0
#     number      int64 8B ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 586MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-20T09:21 GRIB to CDM+CF via cfgrib-0.9.1...
#
# 📊 VARIABLES:
# Data variables:
# ...

# %% [markdown]
# # Checking if the unzipped files are properly cropped or not=>

# %%
import xarray as xr
import numpy as np

nc_file = r"D:\PHD 2025~\PHD\5.ERA5_1980-2025_12Months_DailyPrep_unzipped\ERA5_Land_Rainfall_1991.nc"
ds = xr.open_dataset(nc_file)

# ============================================
# GET LAT-LON RANGE
# ============================================

lat = ds['latitude']
lon = ds['longitude']

print("\n🌍 FULL DATA EXTENT:")
print(f"Latitude range  : {float(lat.min())} to {float(lat.max())}")
print(f"Longitude range : {float(lon.min())} to {float(lon.max())}")

# ============================================
# YOUR STUDY REGION
# ============================================

lat_min, lat_max = 20, 32
lon_min, lon_max = 70, 90

# ============================================
# CHECK IF DATA EXCEEDS STUDY REGION
# ============================================

if (lat.min() < lat_min) or (lat.max() > lat_max) or \
   (lon.min() < lon_min) or (lon.max() > lon_max):
    print("\n⚠️ Dataset is LARGER than study region (not cropped)")
else:
    print("\n✅ Dataset is properly cropped to study region")

# ============================================
# CHECK NaNs OUTSIDE STUDY REGION
# ============================================

precip = ds['tp'].isel(valid_time=0)

# Mask INSIDE region
inside = precip.sel(
    latitude=slice(lat_max, lat_min),
    longitude=slice(lon_min, lon_max)
)

# Mask OUTSIDE region
outside = precip.where(
    ( (ds['latitude'] < lat_min) | (ds['latitude'] > lat_max) ) |
    ( (ds['longitude'] < lon_min) | (ds['longitude'] > lon_max) ),
    drop=True
)

print("\n📊 INSIDE REGION:")
print("Min:", float(inside.min()))
print("Max:", float(inside.max()))
print("NaNs:", int(np.isnan(inside.values).sum()))

print("\n📊 OUTSIDE REGION:")
print("Min:", float(outside.min()))
print("Max:", float(outside.max()))
print("NaNs:", int(np.isnan(outside.values).sum()))

# ============================================
# CHECK % OF NaNs OUTSIDE
# ============================================

total_outside = outside.size
nan_outside = np.isnan(outside.values).sum()

print(f"\n📉 Outside NaN Percentage: {100 * nan_outside / total_outside:.2f}%")
# Out:
# 🌍 FULL DATA EXTENT:
# Latitude range  : 0.0 to 50.0
# Longitude range : 40.0 to 120.0
#
# ⚠️ Dataset is LARGER than study region (not cropped)
#
# 📊 INSIDE REGION:
# Min: 4.351138045421976e-07
# Max: 0.05745353177189827
# NaNs: 863
#
# 📊 OUTSIDE REGION:
# Min: 1.668929030529398e-07
# Max: 0.063630610704422
# NaNs: 154062
#
# 📉 Outside NaN Percentage: 38.39%

# %% [markdown]
# # Checking the single big ass climatology file=>

# %%
import xarray as xr
import numpy as np

# Load file
nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\04_climatology\climatology.nc"
ds = xr.open_dataset(nc_file)

print("\n📂 DATASET SUMMARY:")
print(ds)

# ============================================
# CHECK VARIABLE
# ============================================

print("\n📊 VARIABLES:")
print(ds.data_vars)

# Select precipitation
precip = ds['tp']

# ============================================
# CHECK DIMENSIONS
# ============================================

print("\n📐 DIMENSIONS:")
print(precip.dims)

# ============================================
# DETECT TIME DIMENSION (AUTO FIX)
# ============================================

if 'valid_time' in ds.dims:
    time_dim = 'valid_time'
elif 'time' in ds.dims:
    time_dim = 'time'
elif 'dayofyear' in ds.dims:
    time_dim = 'dayofyear'
else:
    raise ValueError("❌ No recognized time dimension found!")

print(f"\n⏱️ Detected time dimension: {time_dim}")

# ============================================
# CHECK TIME VALUES
# ============================================

print("\n⏱️ TIME VALUES:")
print(ds[time_dim].values[:5])

# ============================================
# SELECT ONE TIMESTEP
# ============================================

# Use safe index (avoid out-of-bounds)
index = min(200, ds.dims[time_dim] - 1)

precip_1 = precip.isel({time_dim: index})

print(f"\n📅 Selected index: {index}")

# ============================================
# BASIC STATS
# ============================================

print("\n📈 STATISTICS (RAW):")
print("Min:", float(precip_1.min()))
print("Max:", float(precip_1.max()))
print("Mean:", float(precip_1.mean()))

# Convert to mm
precip_1_mm = precip_1 * 1000

print("\n📈 STATISTICS (mm):")
print("Min:", float(precip_1_mm.min()))
print("Max:", float(precip_1_mm.max()))
print("Mean:", float(precip_1_mm.mean()))

# ============================================
# CHECK FOR NaNs
# ============================================

print("\n❓ NaN CHECK:")
print("Total NaNs:", int(np.isnan(precip_1.values).sum()))

# ============================================
# CHECK REGION VALUES
# ============================================

# Handle latitude direction automatically
lat = ds['latitude']
lon = ds['longitude']

if lat[0] > lat[-1]:  # descending (ERA5 style)
    precip_region = precip_1.sel(
        latitude=slice(32, 20),
        longitude=slice(70, 90)
    )
else:  # ascending
    precip_region = precip_1.sel(
        latitude=slice(20, 32),
        longitude=slice(70, 90)
    )

print("\n📍 REGION STATS:")
print("Min:", float(precip_region.min()))
print("Max:", float(precip_region.max()))
print("Mean:", float(precip_region.mean()))

# ============================================
# PRINT SAMPLE GRID
# ============================================

print("\n🔍 SAMPLE VALUES:")
print(precip_region.values[0:5, 0:5])
# Out:
# 📂 DATASET SUMMARY:
# <xarray.Dataset> Size: 588MB
# Dimensions:    (dayofyear: 366, latitude: 501, longitude: 801)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 361 362 363 364 365 366
#   * latitude   (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude  (longitude) float64 6kB 40.0 40.1 40.2 40.3 ... 119.8 119.9 120.0
#     number     int64 8B ...
# Data variables:
#     tp         (dayofyear, latitude, longitude) float32 588MB ...
#
# 📊 VARIABLES:
# Data variables:
#     tp       (dayofyear, latitude, longitude) float32 588MB ...
#
# 📐 DIMENSIONS:
# ('dayofyear', 'latitude', 'longitude')
#
# ⏱️ Detected time dimension: dayofyear
#
# ⏱️ TIME VALUES:
# [1 2 3 4 5]
#
# 📅 Selected index: 200
#
# 📈 STATISTICS (RAW):
# Min: 0.0007941144867800176
# Max: 57.283050537109375
# Mean: 3.9505367279052734
#
# 📈 STATISTICS (mm):
# Min: 0.7941144704818726
# Max: 57283.05078125
# Mean: 3950.537109375
#
# ❓ NaN CHECK:
# Total NaNs: 130805
#
# ...

# %% [markdown]
# # Checking the filtered anomaly=>

# %%
import xarray as xr
import numpy as np

# Load file
nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_MJO_LANCZOS\mjo_anom_ERA5_Land_Rainfall_1984.nc"
ds = xr.open_dataset(nc_file)

print("\n📂 DATASET SUMMARY:")
print(ds)

# ============================================
# CHECK VARIABLE
# ============================================

print("\n📊 VARIABLES:")
print(ds.data_vars)

# Select precipitation
precip = ds['tp']

# ============================================
# CHECK DIMENSIONS
# ============================================

print("\n📐 DIMENSIONS:")
print(precip.dims)

# ============================================
# DETECT TIME DIMENSION (AUTO FIX)
# ============================================

if 'valid_time' in ds.dims:
    time_dim = 'valid_time'
elif 'time' in ds.dims:
    time_dim = 'time'
elif 'dayofyear' in ds.dims:
    time_dim = 'dayofyear'
else:
    raise ValueError("❌ No recognized time dimension found!")

print(f"\n⏱️ Detected time dimension: {time_dim}")

# ============================================
# CHECK TIME VALUES
# ============================================

print("\n⏱️ TIME VALUES:")
print(ds[time_dim].values[:5])

# ============================================
# SELECT ONE TIMESTEP
# ============================================

# Use safe index (avoid out-of-bounds)
index = min(200, ds.dims[time_dim] - 1)

precip_1 = precip.isel({time_dim: index})

print(f"\n📅 Selected index: {index}")

# ============================================
# BASIC STATS
# ============================================

print("\n📈 STATISTICS (RAW):")
print("Min:", float(precip_1.min()))
print("Max:", float(precip_1.max()))
print("Mean:", float(precip_1.mean()))

# Convert to mm
precip_1_mm = precip_1 * 1000

print("\n📈 STATISTICS (mm):")
print("Min:", float(precip_1_mm.min()))
print("Max:", float(precip_1_mm.max()))
print("Mean:", float(precip_1_mm.mean()))

# ============================================
# CHECK FOR NaNs
# ============================================

print("\n❓ NaN CHECK:")
print("Total NaNs:", int(np.isnan(precip_1.values).sum()))

# ============================================
# CHECK REGION VALUES
# ============================================

# Handle latitude direction automatically
lat = ds['latitude']
lon = ds['longitude']

if lat[0] > lat[-1]:  # descending (ERA5 style)
    precip_region = precip_1.sel(
        latitude=slice(32, 20),
        longitude=slice(70, 90)
    )
else:  # ascending
    precip_region = precip_1.sel(
        latitude=slice(20, 32),
        longitude=slice(70, 90)
    )

print("\n📍 REGION STATS:")
print("Min:", float(precip_region.min()))
print("Max:", float(precip_region.max()))
print("Mean:", float(precip_region.mean()))

# ============================================
# PRINT SAMPLE GRID
# ============================================

print("\n🔍 SAMPLE VALUES:")
print(precip_region.values[0:5, 0:5])
# Out:
# 📂 DATASET SUMMARY:
# <xarray.Dataset> Size: 395MB
# Dimensions:    (latitude: 501, longitude: 801, time: 246)
# Coordinates:
#   * latitude   (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude  (longitude) float64 6kB 40.0 40.1 40.2 40.3 ... 119.8 119.9 120.0
#   * time       (time) datetime64[ns] 2kB 2000-03-01 2000-03-02 ... 2000-11-01
#     expver     (time) <U4 4kB ...
#     number     int64 8B ...
# Data variables:
#     tp_mjo     (latitude, longitude, time) float32 395MB ...
#
# 📊 VARIABLES:
# Data variables:
#     tp_mjo   (latitude, longitude, time) float32 395MB ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\core\dataset.py in ?(self, name)
#    1237             variable = self._variables[name]
#    1238         except KeyError:
# ...

# %%
import xarray as xr

# Files
raw_file   = r"D:\PHD 2025~\PHD\6.MJO_FILTER\05_anomaly\anom_ERA5_Land_Rainfall_1991.nc"
clean_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_ENSO removed 120DRM\clean_anom_ERA5_Land_Rainfall_1991.nc"

raw   = xr.open_dataset(raw_file)
clean = xr.open_dataset(clean_file)

anom = raw['tp_anomaly']
clean_anom = clean['tp_anomaly']

# Pick a point
lat = 25
lon = 80
day = 150

# Compute manually
window = anom.sel(latitude=lat, longitude=lon, method='nearest')\
             .isel(dayofyear=slice(day-60, day+60))

manual_mean = window.mean().values

raw_val   = anom.sel(latitude=lat, longitude=lon, method='nearest').isel(dayofyear=day).values
clean_val = clean_anom.sel(latitude=lat, longitude=lon, method='nearest').isel(time=day).values

print("\n🔍 MANUAL CHECK:")
print("Raw value       :", raw_val)
print("120-day mean    :", manual_mean)
print("Expected clean  :", raw_val - manual_mean)
print("Actual clean    :", clean_val)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 25
#      22 manual_mean = window.mean().values
#      24 raw_val   = anom.sel(latitude=lat, longitude=lon, method='nearest').isel(dayofyear=day).values
# ---> 25 clean_val = clean_anom.sel(latitude=lat, longitude=lon, method='nearest').isel(time=day).values
#      27 print("\n🔍 MANUAL CHECK:")
#      28 print("Raw value       :", raw_val)
#
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\core\dataarray.py:1594, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1590 coord_indexers = {
#    1591     k: v for k, v in indexers.items() if k in coord_value.dims
#    1592 }
#    1593 if coord_indexers:
# -> 1594     coord_value = coord_value.isel(coord_indexers)
#    1595     if drop and coord_value.ndim == 0:
#    1596         continue
#
# ...

# %%
print(clean_anom)
# Out:
# <xarray.DataArray 'tp_anomaly' (time: 0, latitude: 501, longitude: 801)> Size: 0B
# [0 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 0B
#   * latitude   (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude  (longitude) float64 6kB 40.0 40.1 40.2 40.3 ... 119.8 119.9 120.0
# Attributes: (12/32)
#     GRIB_paramId:                             228
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      401301
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            accum
#     ...                                       ...
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m
#     long_name:                                Total precipitation
#     units:                                    m
# ...

# %% [markdown]
# # Checking the filtered MJO files by plotting=>

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# ============================================
# USER INPUT
# ============================================

lat_min, lat_max = 10, 40
lon_min, lon_max = 50, 100

nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_MJO_LANCZOS\mjo_anom_ERA5_Land_Rainfall_2025.nc"

shapefile_path = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

extent = [40, 120, 0, 50]

# ============================================
# LOAD DATA
# ============================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

print(ds)

# ============================================
# SELECT VARIABLE
# ============================================

precip = ds['tp_mjo']

# Ensure correct dimension order
precip = precip.transpose("time", "latitude", "longitude")

# ============================================
# SELECT ONE DAY (CHANGE INDEX AS NEEDED)
# ============================================

time_index = 200   # 👈 choose your day
precip = precip.isel(time=time_index)

# ============================================
# SUBSET REGION
# ============================================

precip = precip.sel(
    latitude=slice(lat_max, lat_min),   # ERA5 lat is descending
    longitude=slice(lon_min, lon_max)
)

# Fix latitude orientation
precip = precip.sortby('latitude')

# ============================================
# UNIT CONVERSION
# ============================================

precip = precip * 1000   # m → mm

# Optional threshold
precip = precip.where(precip > 1)

# ============================================
# CREATE FIGURE
# ============================================

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(extent, crs=ccrs.PlateCarree())

# ============================================
# PLOT
# ============================================

pcm = ax.pcolormesh(
    precip['longitude'],
    precip['latitude'],
    precip,
    cmap='Blues',
    vmin=0,
    vmax=20,
    transform=ccrs.PlateCarree()
)

# Colorbar
cbar = plt.colorbar(pcm, ax=ax, orientation='vertical', pad=0.02)
cbar.set_label("Rainfall (mm/day)")

# ============================================
# MAP FEATURES
# ============================================

ax.coastlines(resolution='110m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# ============================================
# SHAPEFILE
# ============================================

shape = shpreader.Reader(shapefile_path)
ax.add_geometries(
    shape.geometries(),
    crs=ccrs.PlateCarree(),
    facecolor='none',
    edgecolor='black',
    linewidth=1.5
)

# ============================================
# STUDY REGION BOX
# ============================================

lons = [lon_min, lon_max, lon_max, lon_min, lon_min]
lats = [lat_min, lat_min, lat_max, lat_max, lat_min]

ax.plot(
    lons, lats,
    color='red',
    linewidth=2,
    transform=ccrs.PlateCarree(),
    label='Study Region'
)

# ============================================
# GRIDLINES
# ============================================

gl = ax.gridlines(draw_labels=True, linewidth=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# ============================================
# TITLE
# ============================================

plt.title(f"ERA5 Daily Rainfall (mm) | Time Index = {time_index}", fontsize=14)

plt.legend()
plt.show()
# Out:
# 📂 Loading dataset...
# <xarray.Dataset> Size: 393MB
# Dimensions:    (latitude: 501, longitude: 801, time: 245)
# Coordinates:
#   * latitude   (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude  (longitude) float64 6kB 40.0 40.1 40.2 40.3 ... 119.8 119.9 120.0
#   * time       (time) datetime64[ns] 2kB 2000-03-01 2000-03-02 ... 2000-10-31
#     expver     (time) <U4 4kB ...
#     number     int64 8B ...
# Data variables:
#     tp_mjo     (latitude, longitude, time) float32 393MB ...

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# ============================================
# USER INPUT
# ============================================

lat_min, lat_max = 10, 40
lon_min, lon_max = 50, 100

nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_MJO_LANCZOS\mjo_anom_ERA5_Land_Rainfall_2000.nc"

shapefile_path = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

extent = [40, 120, 0, 50]

# ============================================
# LOAD DATA
# ============================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

print(ds)

# ============================================
# SELECT VARIABLE
# ============================================

precip = ds['tp_mjo']

# Ensure correct dimension order
precip = precip.transpose("time", "latitude", "longitude")

# ============================================
# SELECT ONE DAY (CHANGE INDEX AS NEEDED)
# ============================================

time_index = 200   # 👈 choose your day
precip = precip.isel(time=time_index)

# ============================================
# SUBSET REGION
# ============================================

precip = precip.sel(
    latitude=slice(lat_max, lat_min),   # ERA5 lat is descending
    longitude=slice(lon_min, lon_max)
)

# Fix latitude orientation
precip = precip.sortby('latitude')

# ============================================
# UNIT CONVERSION
# ============================================

precip = precip * 1000   # m → mm

# Optional threshold
precip = precip.where(precip > 1)

# ============================================
# CREATE FIGURE
# ============================================

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(extent, crs=ccrs.PlateCarree())

# ============================================
# PLOT
# ============================================

pcm = ax.pcolormesh(
    precip['longitude'],
    precip['latitude'],
    precip,
    cmap='Blues',
    vmin=0,
    vmax=20,
    transform=ccrs.PlateCarree()
)

# Colorbar
cbar = plt.colorbar(pcm, ax=ax, orientation='vertical', pad=0.02)
cbar.set_label("Rainfall (mm/day)")

# ============================================
# MAP FEATURES
# ============================================

ax.coastlines(resolution='110m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# ============================================
# SHAPEFILE
# ============================================

shape = shpreader.Reader(shapefile_path)
ax.add_geometries(
    shape.geometries(),
    crs=ccrs.PlateCarree(),
    facecolor='none',
    edgecolor='black',
    linewidth=1.5
)

# ============================================
# STUDY REGION BOX
# ============================================

lons = [lon_min, lon_max, lon_max, lon_min, lon_min]
lats = [lat_min, lat_min, lat_max, lat_max, lat_min]

ax.plot(
    lons, lats,
    color='red',
    linewidth=2,
    transform=ccrs.PlateCarree(),
    label='Study Region'
)

# ============================================
# GRIDLINES
# ============================================

gl = ax.gridlines(draw_labels=True, linewidth=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# ============================================
# TITLE
# ============================================

plt.title(f"ERA5 Daily Rainfall (mm) | Time Index = {time_index}", fontsize=14)

plt.legend()
plt.show()
# Out:
# 📂 Loading dataset...
# <xarray.Dataset> Size: 395MB
# Dimensions:    (latitude: 501, longitude: 801, time: 246)
# Coordinates:
#   * latitude   (latitude) float64 4kB 50.0 49.9 49.8 49.7 ... 0.3 0.2 0.1 0.0
#   * longitude  (longitude) float64 6kB 40.0 40.1 40.2 40.3 ... 119.8 119.9 120.0
#   * time       (time) datetime64[ns] 2kB 2000-03-01 2000-03-02 ... 2000-11-01
#     expver     (time) <U4 4kB ...
#     number     int64 8B ...
# Data variables:
#     tp_mjo     (latitude, longitude, time) float32 395MB ...

# %%
import xarray as xr
import pandas as pd
import numpy as np

# ============================================
# USER INPUT (GRID POINT)
# ============================================

lat_point = 25    # 👈 choose your latitude
lon_point = 80    # 👈 choose your longitude

nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_MJO_LANCZOS\mjo_anom_ERA5_Land_Rainfall_2025.nc"

# ============================================
# LOAD DATA
# ============================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

# Ensure correct dimension order
ds = ds.transpose("time", "latitude", "longitude")

# Extract variable
precip = ds["tp_mjo"] * 1000   # convert to mm

# ============================================
# SELECT GRID POINT (nearest)
# ============================================

point_data = precip.sel(
    latitude=lat_point,
    longitude=lon_point,
    method="nearest"
)

print(f"📍 Selected Grid Point: Lat={float(point_data.latitude.values):.2f}, Lon={float(point_data.longitude.values):.2f}")

# ============================================
# CONVERT TO PANDAS
# ============================================

df = point_data.to_dataframe(name="rainfall").reset_index()

# ============================================
# REMOVE ZERO / NaN VALUES
# ============================================

df = df.dropna()
df = df[df["rainfall"] > 0]   # keep only rainy days

# ============================================
# ADD MONTH COLUMN
# ============================================

df["month"] = df["time"].dt.month

# ============================================
# GROUP BY MONTH
# ============================================

grouped = df.groupby("month")

# ============================================
# PRINT RESULTS
# ============================================

print("\n📊 Available Rainy Days at this Grid Point:\n")

for month, group in grouped:
    print(f"\n📅 Month {month}: ({len(group)} days)")
    
    for t in group["time"]:
        print(f"   {t.strftime('%Y-%m-%d')}")
# Out:
# 📂 Loading dataset...
# 📍 Selected Grid Point: Lat=25.00, Lon=80.00
#
# 📊 Available Rainy Days at this Grid Point:
#
#
# 📅 Month 3: (12 days)
#    2000-03-12
#    2000-03-13
#    2000-03-14
#    2000-03-15
#    2000-03-16
#    2000-03-17
#    2000-03-18
#    2000-03-19
#    2000-03-20
#    2000-03-21
#    2000-03-22
#    2000-03-23
#
# 📅 Month 4: (19 days)
#    2000-04-01
#    2000-04-02
#    2000-04-03
#    2000-04-04
#    2000-04-05
#    2000-04-06
#    2000-04-07
#    2000-04-08
#    2000-04-09
#    2000-04-10
#    2000-04-11
#    2000-04-12
#    2000-04-13
#    2000-04-14
#    2000-04-15
#    2000-04-16
#    2000-04-28
#    2000-04-29
#    2000-04-30
#
# 📅 Month 5: (9 days)
#    2000-05-01
#    2000-05-02
#    2000-05-03
#    2000-05-04
#    2000-05-05
#    2000-05-06
#    2000-05-07
#    2000-05-08
#    2000-05-09
#
# 📅 Month 6: (14 days)
#    2000-06-17
#    2000-06-18
#    2000-06-19
#    2000-06-20
#    2000-06-21
#    2000-06-22
#    2000-06-23
#    2000-06-24
# ...

# %%
import xarray as xr
import pandas as pd

# ============================================
# USER INPUT (GRID POINT)
# ============================================

lat_point = 25
lon_point = 80

nc_file = r"D:\PHD 2025~\PHD\6.MJO_FILTER\06_MJO_LANCZOS\mjo_anom_ERA5_Land_Rainfall_2025.nc"

# ============================================
# LOAD DATA
# ============================================

ds = xr.open_dataset(nc_file)
ds = ds.transpose("time", "latitude", "longitude")

precip = ds["tp_mjo"] * 1000   # m → mm

# ============================================
# SELECT GRID POINT
# ============================================

point_data = precip.sel(
    latitude=lat_point,
    longitude=lon_point,
    method="nearest"
)

print(f"📍 Grid Point: Lat={float(point_data.latitude.values):.2f}, Lon={float(point_data.longitude.values):.2f}")

# ============================================
# CONVERT TO DATAFRAME
# ============================================

df = point_data.to_dataframe(name="rainfall").reset_index()

# Remove NaN + keep rainy days
df = df.dropna()
df = df[df["rainfall"] > 0]

# ============================================
# FILTER ONLY OCTOBER
# ============================================

df_oct = df[df["time"].dt.month == 10]

# ============================================
# PRINT RESULTS
# ============================================

print("\n📅 Rainy Days in October:\n")

for t in df_oct["time"]:
    print(t.strftime('%Y-%m-%d'))
# Out:
# 📍 Grid Point: Lat=25.00, Lon=80.00
#
# 📅 Rainy Days in October:
#
# 2000-10-01
# 2000-10-02
# 2000-10-03
# 2000-10-04
# 2000-10-05
# 2000-10-06
# 2000-10-07
# 2000-10-08
# 2000-10-21
# 2000-10-22
# 2000-10-23
# 2000-10-24
# 2000-10-25
# 2000-10-26
# 2000-10-27
# 2000-10-28
# 2000-10-29
# 2000-10-30
# 2000-10-31

# %%
import xarray as xr

file = "D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\ERA5_365D_Daily_Rainfall_1980_2026.nc"

ds = xr.open_dataset(file)

print(ds)
# Out:
# <xarray.Dataset> Size: 872MB
# Dimensions:     (valid_time: 3379, latitude: 201, longitude: 321)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 27kB 1980-01-01 ... 2026-03-19
#     expver      (valid_time) <U4 54kB ...
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 3kB 40.0 40.25 40.5 ... 119.5 119.8 120.0
#     number      int64 8B ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 872MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-24T10:39 GRIB to CDM+CF via cfgrib-0.9.1...
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# ...

# %% [markdown]
# # Crosschecking the huge single precipitation nc file

# %%
import xarray as xr
import matplotlib.pyplot as plt

# ============================================
# LOAD DATA (FIX PATH ISSUE)
# ============================================

file = r"D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\ERA5_365D_Daily_Rainfall_1980_2026.nc"

ds = xr.open_dataset(file)

# ============================================
# SELECT ONE GRID POINT
# (change lat/lon as you like)
# ============================================

lat_point = 20   # example
lon_point = 80   # example

point_data = ds['tp'].sel(
    latitude=lat_point,
    longitude=lon_point,
    method='nearest'
)

# ============================================
# CONVERT TO mm (IMPORTANT)
# ============================================

point_data = point_data * 1000

# ============================================
# PLOT TIME SERIES
# ============================================

plt.figure(figsize=(12, 5))
point_data.plot()

plt.title(f"Daily Rainfall Time Series ({lat_point}, {lon_point})")
plt.xlabel("Time")
plt.ylabel("Rainfall (mm)")

plt.show()

# %%
time_diff = ds.valid_time.to_series().diff().value_counts()
print(time_diff)
# Out:
# valid_time
# 1 days      3238
# 8 days        47
# 283 days      46
# 5 days        35
# 6 days        12
# Name: count, dtype: int64

# %%
ds['year'] = ds.valid_time.dt.year
counts = ds.valid_time.groupby('valid_time.year').count()

print(counts)
# Out:
# <xarray.DataArray 'valid_time' (year: 47)> Size: 376B
# array([72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72,
#        72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72,
#        72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 67])
# Coordinates:
#   * year     (year) int64 376B 1980 1981 1982 1983 1984 ... 2023 2024 2025 2026
#     number   int64 8B ...
# Attributes:
#     long_name:      time
#     standard_name:  time

# %% [markdown]
# # Testing the zipped downloaded nc files=>

# %%
import os

file = r"D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\ERA5_Daily_Prep_1980-2026\ERA5_Daily_Rainfall_1990.nc"

with open(file, "rb") as f:
    header = f.read(4)

print(header)
# Out:
# b'\x89HDF'

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# ============================================
# LOAD FILE
# ============================================

file = r"D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\ERA5_Daily_Prep_1980-2026\ERA5_Daily_Rainfall_1990.nc"
ds = xr.open_dataset(file)

print("\n📦 DATASET OVERVIEW")
print(ds)

# ============================================
# BASIC INFO
# ============================================

print("\n📅 TIME RANGE")
print("Start:", ds.valid_time.values[0])
print("End  :", ds.valid_time.values[-1])
print("Total timesteps:", len(ds.valid_time))

# ============================================
# 1. TIME CONTINUITY CHECK
# ============================================

print("\n⏱️ TIME STEP CHECK")
time_diff = ds.valid_time.to_series().diff().value_counts()
print(time_diff)

# ============================================
# 2. YEARLY DATA COUNT
# ============================================

print("\n📊 YEAR-WISE DATA COUNT")
year_counts = ds.valid_time.groupby('valid_time.year').count()
print(year_counts)

# ============================================
# 3. CHECK FOR NaNs
# ============================================

print("\n❓ NaN CHECK")
nan_count = ds['tp'].isnull().sum().values
print("Total NaNs:", nan_count)

# ============================================
# 4. VALUE RANGE CHECK (convert to mm)
# ============================================

tp_mm = ds['tp'] * 1000

print("\n📏 VALUE RANGE (mm)")
print("Min:", float(tp_mm.min()))
print("Max:", float(tp_mm.max()))
print("Mean:", float(tp_mm.mean()))

# ============================================
# 5. RANDOM GRID TIME SERIES CHECK
# ============================================

lat_point = 20
lon_point = 80

ts = tp_mm.sel(latitude=lat_point, longitude=lon_point, method='nearest')

plt.figure(figsize=(12,4))
ts.plot()
plt.title("Sample Time Series (Sanity Check)")
plt.show()

# ============================================
# 6. MONTHLY CLIMATOLOGY CHECK
# ============================================

monthly = tp_mm.groupby('valid_time.month').mean()

plt.figure()
monthly.sel(latitude=lat_point, longitude=lon_point, method='nearest').plot()
plt.title("Monthly Climatology")
plt.show()

# ============================================
# 7. SINGLE DAY MAP CHECK
# ============================================

plt.figure()
tp_mm.isel(valid_time=100).plot()
plt.title("Spatial Map Check")
plt.show()
# Out:
# 📦 DATASET OVERVIEW
# <xarray.Dataset> Size: 94MB
# Dimensions:     (valid_time: 365, latitude: 201, longitude: 321)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 3kB 1990-01-01 ... 1990-12-31
#     expver      (valid_time) <U4 6kB ...
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 3kB 40.0 40.25 40.5 ... 119.5 119.8 120.0
#     number      int64 8B ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 94MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-24T10:59 GRIB to CDM+CF via cfgrib-0.9.1...
#
# 📅 TIME RANGE
# Start: 1990-01-01T00:00:00.000000000
# End  : 1990-12-31T00:00:00.000000000
# ...

# %% [markdown]
# # Inspecting the CDO merged precipitation file=>

# %%
import xarray as xr

# ============================================
# FILE PATH
# ============================================
file_path = r"D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc"   # 🔁 change this

# ============================================
# OPEN DATASET
# ============================================
ds = xr.open_dataset(file_path)

print("\n================ DATASET SUMMARY ================\n")
print(ds)

# ============================================
# DIMENSIONS
# ============================================
print("\n================ DIMENSIONS ================\n")
for dim, size in ds.dims.items():
    print(f"{dim}: {size}")

# ============================================
# COORDINATES
# ============================================
print("\n================ COORDINATES ================\n")
for coord in ds.coords:
    print(f"\n🔹 {coord}")
    print(ds[coord])

# ============================================
# VARIABLES
# ============================================
print("\n================ VARIABLES ================\n")
for var in ds.data_vars:
    print(f"\n🔸 {var}")
    print(ds[var])

# ============================================
# ATTRIBUTES
# ============================================
print("\n================ GLOBAL ATTRIBUTES ================\n")
for attr, value in ds.attrs.items():
    print(f"{attr}: {value}")

# ============================================
# VARIABLE ATTRIBUTES
# ============================================
print("\n================ VARIABLE ATTRIBUTES ================\n")
for var in ds.data_vars:
    print(f"\n🔸 {var}")
    for attr, value in ds[var].attrs.items():
        print(f"   {attr}: {value}")

# ============================================
# QUICK STATS (VERY IMPORTANT)
# ============================================
print("\n================ BASIC STATISTICS ================\n")
for var in ds.data_vars:
    print(f"\n🔸 {var}")
    print(f"Min: {ds[var].min().values}")
    print(f"Max: {ds[var].max().values}")
    print(f"Mean: {ds[var].mean().values}")

# ============================================
# CHECK TIME FORMAT (CRITICAL)
# ============================================
if "time" in ds.coords:
    print("\n================ TIME INFO ================\n")
    print(ds.time)
    print("First time:", ds.time.values[0])
    print("Last time :", ds.time.values[-1])

# ============================================
# CHECK LAT/LON RANGE
# ============================================
if "latitude" in ds.coords:
    print("\nLatitude range:", ds.latitude.values.min(), "to", ds.latitude.values.max())

if "longitude" in ds.coords:
    print("Longitude range:", ds.longitude.values.min(), "to", ds.longitude.values.max())

print("\n✅ Done inspecting dataset!")
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsTimedelta                      Traceback (most recent call last)
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\coding\times.py:563, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     562 try:
# --> 563     dates = _decode_datetime_with_pandas(
#     564         flat_num_dates, units, calendar, time_unit
#     565     )
#     566 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\coding\times.py:509, in _decode_datetime_with_pandas(flat_num_dates, units, calendar, time_resolution)
#     507 if flat_num_dates.size > 0:
#     508     # avoid size 0 datetimes GH1329
# --> 509     _check_date_for_units_since_refdate(
#     510         flat_num_dates.min(), time_unit, ref_date
#     511     )
#     512     _check_date_for_units_since_refdate(
# ...

# %%
import xarray as xr

file_path = r"D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc"

ds = xr.open_dataset(file_path, decode_times=False)

print(ds)
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:     (valid_time: 16869, latitude: 201, longitude: 321)
# Coordinates:
#   * valid_time  (valid_time) float64 135kB -9.883e+228 4.015e-26 ... 2.26e-49
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 3kB 40.0 40.25 40.5 ... 119.5 119.8 120.0
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 4GB ...
# Attributes:
#     CDI:                     Climate Data Interface version 2.4.0 (https://mp...
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     history:                 Tue Mar 24 18:01:50 2026: cdo mergetime ERA5_Dai...
#     CDO:                     Climate Data Operators version 2.4.0 (https://mp...

# %% [markdown]
# # Fixing the corrupted CDO file =>

# %% [markdown]
# ### 🟢 Step 1 — Open safely

# %%
import xarray as xr

ds = xr.open_dataset("D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc", decode_times=False)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\hp\AppData\Local\Temp\ipykernel_7964\1845853444.py:3: SyntaxWarning: invalid escape sequence '\P'
#   ds = xr.open_dataset("D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc", decode_times=False)

# %% [markdown]
# ### 🟢 Step 2 — Fix time axis (CRITICAL)

# %%
import pandas as pd

n = ds.dims['valid_time']

ds = ds.assign_coords(
    valid_time=pd.date_range("1980-01-01", periods=n, freq="D")
)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7964\1249415194.py:3: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   n = ds.dims['valid_time']

# %% [markdown]
# ### 🟢 Step 3 — Rename time (IMPORTANT for future code

# %%
ds = ds.rename({'valid_time': 'time'})

# %% [markdown]
# ### 🟢 Step 4 — Check precipitation units

# %%
print(ds['tp'].attrs)
# Out:
# {'standard_name': 'unknown', 'long_name': 'Total precipitation', 'units': 'm', 'GRIB_paramId': np.int32(228), 'GRIB_dataType': 'fc', 'GRIB_numberOfPoints': np.int32(64521), 'GRIB_typeOfLevel': 'surface', 'GRIB_stepUnits': np.int32(1), 'GRIB_stepType': 'accum', 'GRIB_gridType': 'regular_ll', 'GRIB_uvRelativeToGrid': np.int32(0), 'GRIB_NV': np.int32(0), 'GRIB_Nx': np.int32(321), 'GRIB_Ny': np.int32(201), 'GRIB_cfName': 'unknown', 'GRIB_cfVarName': 'tp', 'GRIB_gridDefinitionDescription': 'Latitude/Longitude Grid', 'GRIB_iDirectionIncrementInDegrees': np.float64(0.25), 'GRIB_iScansNegatively': np.int32(0), 'GRIB_jDirectionIncrementInDegrees': np.float64(0.25), 'GRIB_jPointsAreConsecutive': np.int32(0), 'GRIB_jScansPositively': np.int32(0), 'GRIB_latitudeOfFirstGridPointInDegrees': np.float64(50.0), 'GRIB_latitudeOfLastGridPointInDegrees': np.float64(0.0), 'GRIB_longitudeOfFirstGridPointInDegrees': np.float64(40.0), 'GRIB_longitudeOfLastGridPointInDegrees': np.float64(120.0), 'GRIB_missin
# ...

# %% [markdown]
# ### 🔥 Convert to mm (MANDATORY)

# %%
ds['tp'] = ds['tp'] * 1000
ds['tp'].attrs['units'] = 'mm'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 ds['tp'] = ds['tp'] * 1000
#       2 ds['tp'].attrs['units'] = 'mm'
#
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\core\_typed_ops.py:552, in DataArrayOpsMixin.__mul__(self, other)
#     551 def __mul__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 552     return self._binary_op(other, operator.mul)
#
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\core\dataarray.py:4905, in DataArray._binary_op(self, other, f, reflexive)
#    4901 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4902 other_coords = getattr(other, "coords", None)
#    4904 variable = (
# -> 4905     f(self.variable, other_variable_or_arraylike)
#    4906     if not reflexive
#    4907     else f(other_variable_or_arraylike, self.variable)
# ...

# %%
import xarray as xr

ds = xr.open_dataset(
    "D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc",
    decode_times=False,
    chunks={'valid_time': 100}   # 👈 VERY IMPORTANT
)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\hp\AppData\Local\Temp\ipykernel_7964\3071631235.py:4: SyntaxWarning: invalid escape sequence '\P'
#   "D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc",

# %%
ds['tp'] = ds['tp'] * 1000

# %%
import numpy as np

print("\n--- BASIC INFO ---")
print(ds)

print("\n--- TIME CHECK ---")
print(ds['valid_time'].values[:3])
print(ds['valid_time'].values[-3:])

print("\n--- VALUE RANGE ---")
print("Min:", ds['tp'].min().values)
print("Max:", ds['tp'].max().values)

print("\n--- NaN COUNT ---")
print(np.isnan(ds['tp']).sum().values)

print("\n--- SAMPLE GRID CHECK ---")
print(ds['tp'].isel(valid_time=0).values[:5, :5])

print("\n--- LOAD TEST (IMPORTANT) ---")
ds.load()

print("✅ DATASET FULLY WORKING")
# Out:
# --- BASIC INFO ---
# <xarray.Dataset> Size: 4GB
# Dimensions:     (valid_time: 16869, latitude: 201, longitude: 321)
# Coordinates:
#   * valid_time  (valid_time) float64 135kB -9.883e+228 4.015e-26 ... 2.26e-49
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 3kB 40.0 40.25 40.5 ... 119.5 119.8 120.0
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 4GB dask.array<chunksize=(100, 201, 321), meta=np.ndarray>
# Attributes:
#     CDI:                     Climate Data Interface version 2.4.0 (https://mp...
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     history:                 Tue Mar 24 18:01:50 2026: cdo mergetime ERA5_Dai...
# ...

# %%
import xarray as xr

ds = xr.open_dataset("D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc")
print(ds)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\hp\AppData\Local\Temp\ipykernel_7964\2185830375.py:3: SyntaxWarning: invalid escape sequence '\P'
#   ds = xr.open_dataset("D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc")
# C:\Users\hp\AppData\Local\Temp\ipykernel_7964\2185830375.py:3: SyntaxWarning: invalid escape sequence '\P'
#   ds = xr.open_dataset("D:\PHD 2025~\PHD DOWNLOADS\PRECEPITATION\CDO_Merged_Prep_1980-2026\ERA5_CDO_merged_1980_2026.nc")
# ---------------------------------------------------------------------------
# OutOfBoundsTimedelta                      Traceback (most recent call last)
# File d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\xarray\coding\times.py:563, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     562 try:
# --> 563     dates = _decode_datetime_with_pandas(
# ...

# %% [markdown]
# # Inspecting the lanczos file for garbage value=>

# %%
import xarray as xr
import numpy as np

# =====================================================
# FILE PATH
# =====================================================

nc_file = r"E:\IIT KGP 2025\SERVER_1\mjo_lanczos.nc"

# =====================================================
# LOAD DATA
# =====================================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

var_name = list(ds.data_vars)[0]
print(f"🔎 Variable: {var_name}")

data = ds[var_name]

# Convert to numpy
arr = data.values

# =====================================================
# BASIC COUNTS
# =====================================================

total = arr.size

nan_count = np.isnan(arr).sum()
pos_inf = np.isposinf(arr).sum()
neg_inf = np.isneginf(arr).sum()
inf_total = pos_inf + neg_inf

# Extreme threshold (adjust if needed)
threshold = 1e5
extreme_count = np.sum(np.abs(arr) > threshold)

# =====================================================
# PRINT RESULTS
# =====================================================

print("\n📊 ===== DATA QUALITY REPORT =====")

print(f"Total values        : {total:,}")
print(f"NaN values          : {nan_count:,}")
print(f"+Inf values         : {pos_inf:,}")
print(f"-Inf values         : {neg_inf:,}")
print(f"Total Inf           : {inf_total:,}")
print(f"Extreme (>1e5)      : {extreme_count:,}")

print("\n📊 ===== PERCENTAGE =====")

print(f"NaN %               : {100*nan_count/total:.4f}%")
print(f"Inf %               : {100*inf_total/total:.4f}%")
print(f"Extreme %           : {100*extreme_count/total:.4f}%")

# =====================================================
# MIN / MAX (SAFE)
# =====================================================

finite_arr = arr[np.isfinite(arr)]

if finite_arr.size > 0:
    print("\n📊 ===== VALID RANGE =====")
    print("Min (finite):", np.min(finite_arr))
    print("Max (finite):", np.max(finite_arr))
else:
    print("❌ No finite values found!")

# =====================================================
# OPTIONAL: WHERE ARE EXTREME VALUES
# =====================================================

idx = np.where(np.abs(arr) > threshold)

if len(idx[0]) > 0:
    print("\n📍 Example extreme value locations (first 5):")

    for i in range(min(5, len(idx[0]))):
        t = idx[0][i]
        lat = idx[1][i]
        lon = idx[2][i]

        print(f"Time index: {t}, Lat index: {lat}, Lon index: {lon}, Value: {arr[t, lat, lon]}")

print("\n✅ Analysis complete!")
# Out:
# 📂 Loading dataset...
# 🔎 Variable: tp_mjo
#
# 📊 ===== DATA QUALITY REPORT =====
# Total values        : 1,084,081,842
# NaN values          : 0
# +Inf values         : 0
# -Inf values         : 0
# Total Inf           : 0
# Extreme (>1e5)      : 0
#
# 📊 ===== PERCENTAGE =====
# NaN %               : 0.0000%
# Inf %               : 0.0000%
# Extreme %           : 0.0000%
#
# 📊 ===== VALID RANGE =====
# Min (finite): -2.657104689763329
# Max (finite): 3.9521874865505517
#
# ✅ Analysis complete!

# %% [markdown]
# # Ploting phase 1=>

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# =====================================================
# FILE PATHS
# =====================================================

nc_file = r"D:\PHD 2025~\PHD\1.MJO Composites\MJO_Phase_1_Composite.nc"
shapefile = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# =====================================================
# LOAD DATA
# =====================================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

var_name = list(ds.data_vars)[0]
print(f"🔎 Variable: {var_name}")

data = ds[var_name]

# =====================================================
# SELECT INDIA REGION
# =====================================================

data = data.sel(
    latitude=slice(5, 40),
    longitude=slice(65, 100)
)

# =====================================================
# PREPARE DATA
# =====================================================

data_np = data.values

# Remove any remaining inf (just in case)
data_np = np.where(np.isfinite(data_np), data_np, np.nan)

# =====================================================
# COLOR SCALE (SYMMETRIC)
# =====================================================

vmax = np.nanpercentile(np.abs(data_np), 99)  # robust scaling
levels = np.linspace(-vmax, vmax, 21)

print("📊 Plot range:", -vmax, "to", vmax)

# =====================================================
# PLOT
# =====================================================

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

cf = ax.contourf(
    data.longitude,
    data.latitude,
    data_np,
    levels=levels,
    cmap="RdBu_r",
    extend="both",
    transform=ccrs.PlateCarree()
)

# =====================================================
# SHAPEFILE
# =====================================================

shape_feature = cfeature.ShapelyFeature(
    shpreader.Reader(shapefile).geometries(),
    ccrs.PlateCarree(),
    edgecolor='black',
    facecolor='none',
    linewidth=1
)

ax.add_feature(shape_feature)

# =====================================================
# MAP FEATURES
# =====================================================

ax.coastlines(resolution='10m')
ax.add_feature(cfeature.BORDERS, linestyle=':')

ax.set_extent([65, 100, 5, 40])

# =====================================================
# COLORBAR
# =====================================================

cbar = plt.colorbar(cf, ax=ax, orientation='horizontal', pad=0.05)
cbar.set_label(var_name)

# =====================================================
# TITLE
# =====================================================

ax.set_title("MJO Phase 1 Composite (Amp ≥ 1)", fontsize=14)

plt.tight_layout()
plt.show()

print("✅ Plot completed!")
# Out:
# 📂 Loading dataset...
# 🔎 Variable: tp_mjo_composite
# 📊 Plot range: -0.13151506254152548 to 0.13151506254152548
# d:\PHD 2025~\PHD\VS CODES\era5_env\Lib\site-packages\cartopy\io\__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# ✅ Plot completed!

# %% [markdown]
# # Seeing phase 2=>

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# =====================================================
# FILE PATHS
# =====================================================

nc_file = r"D:\PHD 2025~\PHD\1.MJO Composites\MJO_Phase_2_Composite.nc"
shapefile = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# =====================================================
# LOAD DATA
# =====================================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

var_name = list(ds.data_vars)[0]
print(f"🔎 Variable: {var_name}")

data = ds[var_name]

# =====================================================
# SELECT INDIA REGION
# =====================================================

data = data.sel(
    latitude=slice(5, 40),
    longitude=slice(65, 100)
)

# =====================================================
# PREPARE DATA
# =====================================================

data_np = data.values

# Remove any remaining inf (just in case)
data_np = np.where(np.isfinite(data_np), data_np, np.nan)

# =====================================================
# COLOR SCALE (SYMMETRIC)
# =====================================================

vmax = np.nanpercentile(np.abs(data_np), 99)  # robust scaling
levels = np.linspace(-vmax, vmax, 21)

print("📊 Plot range:", -vmax, "to", vmax)

# =====================================================
# PLOT
# =====================================================

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

cf = ax.contourf(
    data.longitude,
    data.latitude,
    data_np,
    levels=levels,
    cmap="RdBu_r",
    extend="both",
    transform=ccrs.PlateCarree()
)

# =====================================================
# SHAPEFILE
# =====================================================

shape_feature = cfeature.ShapelyFeature(
    shpreader.Reader(shapefile).geometries(),
    ccrs.PlateCarree(),
    edgecolor='black',
    facecolor='none',
    linewidth=1
)

ax.add_feature(shape_feature)

# =====================================================
# MAP FEATURES
# =====================================================

ax.coastlines(resolution='10m')
ax.add_feature(cfeature.BORDERS, linestyle=':')

ax.set_extent([65, 100, 5, 40])

# =====================================================
# COLORBAR
# =====================================================

cbar = plt.colorbar(cf, ax=ax, orientation='horizontal', pad=0.05)
cbar.set_label(var_name)

# =====================================================
# TITLE
# =====================================================

ax.set_title("MJO Phase 2 Composite (Amp ≥ 1)", fontsize=14)

plt.tight_layout()
plt.show()

print("✅ Plot completed!")
# Out:
# 📂 Loading dataset...
# 🔎 Variable: tp_mjo_composite
# 📊 Plot range: -0.15363011550843086 to 0.15363011550843086
# ✅ Plot completed!

# %% [markdown]
# # Testing the 2025 phase=>

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# =====================================================
# FILE PATHS
# =====================================================

nc_file = r"D:\PHD 2025~\PHD\2.MJO Composites 2025\MJO_2025_Phase_4_Composite.nc"
shapefile = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# =====================================================
# LOAD DATA
# =====================================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

var_name = list(ds.data_vars)[0]
print(f"🔎 Variable: {var_name}")

data = ds[var_name]

# =====================================================
# SELECT INDIA REGION
# =====================================================

data = data.sel(
    latitude=slice(5, 40),
    longitude=slice(65, 100)
)

# =====================================================
# PREPARE DATA
# =====================================================

data_np = data.values

# Remove any remaining inf (just in case)
data_np = np.where(np.isfinite(data_np), data_np, np.nan)

# =====================================================
# COLOR SCALE (SYMMETRIC)
# =====================================================

vmax = np.nanpercentile(np.abs(data_np), 99)  # robust scaling
levels = np.linspace(-vmax, vmax, 21)

print("📊 Plot range:", -vmax, "to", vmax)

# =====================================================
# PLOT
# =====================================================

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

cf = ax.contourf(
    data.longitude,
    data.latitude,
    data_np,
    levels=levels,
    cmap="RdBu_r",
    extend="both",
    transform=ccrs.PlateCarree()
)

# =====================================================
# SHAPEFILE
# =====================================================

shape_feature = cfeature.ShapelyFeature(
    shpreader.Reader(shapefile).geometries(),
    ccrs.PlateCarree(),
    edgecolor='black',
    facecolor='none',
    linewidth=1
)

ax.add_feature(shape_feature)

# =====================================================
# MAP FEATURES
# =====================================================

ax.coastlines(resolution='10m')
ax.add_feature(cfeature.BORDERS, linestyle=':')

ax.set_extent([65, 100, 5, 40])

# =====================================================
# COLORBAR
# =====================================================

cbar = plt.colorbar(cf, ax=ax, orientation='horizontal', pad=0.05)
cbar.set_label(var_name)

# =====================================================
# TITLE
# =====================================================

ax.set_title("MJO Phase 4 Composite (Amp ≥ 1)", fontsize=14)

plt.tight_layout()
plt.show()

print("✅ Plot completed!")
# Out:
# 📂 Loading dataset...
# 🔎 Variable: tp_mjo_composite
# 📊 Plot range: -0.6839945933068662 to 0.6839945933068662
# ✅ Plot completed!

# %% [markdown]
# # Ploting all the phases at once =>

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import os

# =====================================================
# PATHS
# =====================================================

data_dir = r"D:\PHD 2025~\PHD\1.MJO Composites"
shapefile = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# =====================================================
# LOAD ALL PHASE DATA
# =====================================================

phase_data = []

for phase in range(1, 9):
    file = os.path.join(data_dir, f"MJO_Phase_{phase}_Composite.nc")
    
    ds = xr.open_dataset(file)
    var_name = list(ds.data_vars)[0]
    
    data = ds[var_name].sel(
        latitude=slice(5, 40),
        longitude=slice(65, 100)
    )
    
    arr = data.values
    arr = np.where(np.isfinite(arr), arr, np.nan)
    
    phase_data.append(arr)

lats = data.latitude
lons = data.longitude

# =====================================================
# COMMON COLOR SCALE (VERY IMPORTANT)
# =====================================================

all_data = np.stack(phase_data)

vmax = np.nanpercentile(np.abs(all_data), 99)
levels = np.linspace(-vmax, vmax, 21)

print("📊 Common color range:", -vmax, "to", vmax)

# =====================================================
# PLOT
# =====================================================

fig, axes = plt.subplots(
    nrows=2, ncols=4,
    figsize=(18, 8),
    subplot_kw={'projection': ccrs.PlateCarree()}
)

axes = axes.flatten()

for i, ax in enumerate(axes):
    
    phase = i + 1
    data_np = phase_data[i]
    
    cf = ax.contourf(
        lons,
        lats,
        data_np,
        levels=levels,
        cmap="RdBu_r",
        extend="both",
        transform=ccrs.PlateCarree()
    )
    
    # Shapefile
    shape_feature = cfeature.ShapelyFeature(
        shpreader.Reader(shapefile).geometries(),
        ccrs.PlateCarree(),
        edgecolor='black',
        facecolor='none',
        linewidth=0.8
    )
    ax.add_feature(shape_feature)
    
    # Map features
    ax.coastlines(resolution='10m', linewidth=0.5)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    
    ax.set_extent([65, 100, 5, 40])
    
    ax.set_title(f"Phase {phase}", fontsize=11)

# =====================================================
# COMMON COLORBAR
# =====================================================

cbar = fig.colorbar(
    cf,
    ax=axes,
    orientation='horizontal',
    fraction=0.05,
    pad=0.08
)

cbar.set_label(var_name)

# =====================================================
# TITLE
# =====================================================

fig.suptitle("MJO Phase Composites (Amp ≥ 1)", fontsize=16)

plt.tight_layout()
plt.show()

print("✅ 8-phase plot completed!")
# Out:
# 📊 Common color range: -0.17232203588862724 to 0.17232203588862724
# C:\Users\hp\AppData\Local\Temp\ipykernel_8704\668211733.py:117: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ✅ 8-phase plot completed!

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import numpy as np

# =====================================================
# FILE PATHS
# =====================================================

nc_file = r"D:\PHD 2025~\PHD\1.MJO Composites - Copy\MJO_Phase_1_Composite.nc"
shapefile = r"D:\PHD 2025~\PHD\Shapefiles\India Shapefile With Kashmir\India Shape\india_st.shp"

# =====================================================
# LOAD DATA
# =====================================================

print("📂 Loading dataset...")
ds = xr.open_dataset(nc_file)

var_name = list(ds.data_vars)[0]
print(f"🔎 Using variable: {var_name}")

data = ds[var_name]

# =====================================================
# SELECT INDIA REGION
# =====================================================

data = data.sel(
    latitude=slice(5, 40),
    longitude=slice(65, 100)
)

# =====================================================
# CLEAN DATA (CRITICAL STEP)
# =====================================================

data_np = data.values

# Replace inf with NaN
data_np = np.where(np.isfinite(data_np), data_np, np.nan)

print("\n📊 After cleaning:")
print("Min:", np.nanmin(data_np))
print("Max:", np.nanmax(data_np))
print("NaN count:", np.isnan(data_np).sum())

# If all NaN → stop
if np.isnan(data_np).all():
    raise ValueError("❌ Data became all NaN after removing infinities")

# =====================================================
# CREATE LEVELS (SYMMETRIC)
# =====================================================

abs_max = np.nanmax(np.abs(data_np))

if abs_max == 0 or np.isnan(abs_max):
    raise ValueError("❌ Invalid data range")

levels = np.linspace(-abs_max, abs_max, 21)

# =====================================================
# PLOT
# =====================================================

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

cf = ax.contourf(
    data.longitude,
    data.latitude,
    data_np,
    levels=levels,
    cmap="RdBu_r",
    extend="both",
    transform=ccrs.PlateCarree()
)

# =====================================================
# SHAPEFILE
# =====================================================

shape_feature = cfeature.ShapelyFeature(
    shpreader.Reader(shapefile).geometries(),
    ccrs.PlateCarree(),
    edgecolor='black',
    facecolor='none',
    linewidth=1
)

ax.add_feature(shape_feature)

# =====================================================
# MAP FEATURES
# =====================================================

ax.coastlines(resolution='10m')
ax.add_feature(cfeature.BORDERS, linestyle=':')

ax.set_extent([65, 100, 5, 40])

# =====================================================
# COLORBAR
# =====================================================

cbar = plt.colorbar(cf, ax=ax, orientation='horizontal', pad=0.05)
cbar.set_label(var_name)

# =====================================================
# TITLE
# =====================================================

ax.set_title("MJO Phase 3 Composite (Cleaned)", fontsize=14)

plt.tight_layout()
plt.show()

print("✅ Plot successful!")
# Out:
# 📂 Loading dataset...
# 🔎 Using variable: tp_mjo_composite
#
# 📊 After cleaning:
# Min: -1.231270830764647e+306
# Max: 1.2357788725364193e+306
# NaN count: 42
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 72
#      69 fig = plt.figure(figsize=(10, 8))
#      70 ax = plt.axes(projection=ccrs.PlateCarree())
# ---> 72 cf = ax.contourf(
#      73     data.longitude,
#      74     data.latitude,
#      75     data_np,
#      76     levels=levels,
#      77     cmap="RdBu_r",
#      78     extend="both",
#      79     transform=ccrs.PlateCarree()
#      80 )
#      82 # =====================================================
#      83 # SHAPEFILE
#      84 # =====================================================
#      86 shape_feature = cfeature.ShapelyFeature(
#      87     shpreader.Reader(shapefile).geometries(),
#      88     ccrs.PlateCarree(),
# ...
