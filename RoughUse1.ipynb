# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. DEFINE COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 50, 90
plot_lat_min, plot_lat_max = 10, 50

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 72, 82
study_lat_min, study_lat_max = 26, 38

# ===============================
# 2. LOAD INDIA SHAPEFILE
# ===============================
# 👉 Change this path to where your India shapefile is stored
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. CREATE FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Set plot extent
ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. ADD INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="black",
    linewidth=1
)

# ===============================
# 5. CREATE BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot extent box (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    label="Plot extent"
)

# Study area box (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    label="Study area"
)

# ===============================
# 6. GRIDLINES & LABELS
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linewidth=0.5,
    color="gray",
    alpha=0.5,
    linestyle="--"
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 7. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 50, 90
plot_lat_min, plot_lat_max = 10, 50

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 72, 82
study_lat_min, study_lat_max = 26, 38

# ===============================
# 2. INDIA SHAPEFILE
# ===============================
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="lightgray",
    edgecolor="black",
    linewidth=0.8,
    zorder=2
)

# ===============================
# 5. COASTLINES (CARTOPY)
# ===============================
ax.coastlines(
    resolution="110m",   # "110m", "50m", "10m"
    linewidth=1.0,
    zorder=3
)

# ===============================
# 6. BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot domain (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    zorder=4
)

# Study area (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    zorder=4
)

# ===============================
# 7. GRIDLINES
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linestyle="--",
    linewidth=0.5,
    alpha=0.6
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 8. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 60, 100
plot_lat_min, plot_lat_max = 0, 50

# North, West, South, East
area = [40, 60, 5, 100]

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 72, 82
study_lat_min, study_lat_max = 26, 38

# ===============================
# 2. INDIA SHAPEFILE
# ===============================
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="lightgray",
    edgecolor="black",
    linewidth=0.8,
    zorder=2
)

# ===============================
# 5. COASTLINES (CARTOPY)
# ===============================
ax.coastlines(
    resolution="110m",   # "110m", "50m", "10m"
    linewidth=1.0,
    zorder=3
)

# ===============================
# 6. BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot domain (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    zorder=4
)

# Study area (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    zorder=4
)

# ===============================
# 7. GRIDLINES
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linestyle="--",
    linewidth=0.5,
    alpha=0.6
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 8. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
from shapely.geometry import box

# ===============================
# 1. COORDINATES
# ===============================

# ---- Plot extent (larger box) ----
plot_lon_min, plot_lon_max = 60, 100
plot_lat_min, plot_lat_max = 0, 50

# North, West, South, East
area = [40, 60, 5, 100]

# ---- Study area (smaller box) ----
study_lon_min, study_lon_max = 72, 82
study_lat_min, study_lat_max = 26, 38

# ===============================
# 2. INDIA SHAPEFILE
# ===============================
india_shp_path = r"/media/nilay/HDD/IIT KGP 2025/PHD/Shapefiles/India Shapefile With Kashmir/India Shape/india_st.shp"

reader = shpreader.Reader(india_shp_path)
india_geom = list(reader.geometries())

# ===============================
# 3. FIGURE
# ===============================
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(
    [plot_lon_min, plot_lon_max, plot_lat_min, plot_lat_max],
    crs=ccrs.PlateCarree()
)

# ===============================
# 4. INDIA BOUNDARY
# ===============================
ax.add_geometries(
    india_geom,
    crs=ccrs.PlateCarree(),
    facecolor="lightgray",
    edgecolor="black",
    linewidth=0.8,
    zorder=2
)

# ===============================
# 5. COASTLINES (CARTOPY)
# ===============================
ax.coastlines(
    resolution="110m",   # "110m", "50m", "10m"
    linewidth=1.0,
    zorder=3
)

# ===============================
# 6. BOXES
# ===============================
plot_box = box(plot_lon_min, plot_lat_min, plot_lon_max, plot_lat_max)
study_box = box(study_lon_min, study_lat_min, study_lon_max, study_lat_max)

# Plot domain (RED)
ax.add_geometries(
    [plot_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    zorder=4
)

# Study area (BLUE)
ax.add_geometries(
    [study_box],
    crs=ccrs.PlateCarree(),
    facecolor="none",
    edgecolor="blue",
    linewidth=2,
    zorder=4
)

# ===============================
# 7. GRIDLINES
# ===============================
gl = ax.gridlines(
    draw_labels=True,
    linestyle="--",
    linewidth=0.5,
    alpha=0.6
)
gl.top_labels = False
gl.right_labels = False

# ===============================
# 8. TITLE
# ===============================
ax.set_title("Study Area within Plot Domain (Lat–Lon)", fontsize=12)

plt.show()

# %%
pip install netCDF4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cdsapi
import os
import xarray as xr
import glob

# =====================================================
# USER SETTINGS
# =====================================================

out_dir = "/home/nilay/SSD Data Downloads/ERA5_CLIM"
os.makedirs(out_dir, exist_ok=True)

final_file = os.path.join(out_dir, "ERA5_Climatology_1980_2025.nc")

years = range(2019, 2020)
months = ["10"]

# North, West, South, East
area = [50, 60, 0, 100]
#area = None

c = cdsapi.Client()

# =====================================================
# DOWNLOAD SINGLE LEVEL DATA
# =====================================================

single_files = []

for y in years:

    year_str = str(y)
    out_file = os.path.join(out_dir, f"ERA5_single_{year_str}.nc")

    single_files.append(out_file)

    if os.path.exists(out_file):
        print("✅ Skip single:", year_str)
        continue

    print("⬇ Downloading single level:", year_str)

    request = {
        "product_type": "reanalysis",
        "variable": [
            "total_precipitation",
            "vertical_integral_of_divergence_of_moisture_flux",
            "vertical_integral_of_eastward_water_vapour_flux",
            "vertical_integral_of_northward_water_vapour_flux"
        ],
        "year": year_str,
        "month": months,
        "day": [f"{d:02d}" for d in range(1, 32)],
        "daily_statistic": "daily_mean",
        "time_zone": "utc+00:00",
        "frequency": "1_hourly",
        "data_format": "netcdf",
        "area": area
    }

    c.retrieve(
        "derived-era5-single-levels-daily-statistics",
        request,
        out_file
    )

# =====================================================
# DOWNLOAD PRESSURE LEVEL DATA
# =====================================================

pl_files = []

for y in years:

    year_str = str(y)
    out_file = os.path.join(out_dir, f"ERA5_pl_{year_str}.nc")

    pl_files.append(out_file)

    if os.path.exists(out_file):
        print("✅ Skip pressure:", year_str)
        continue

    print("⬇ Downloading pressure level:", year_str)

    request = {
        "product_type": "reanalysis",
        "variable": [
            "geopotential",
            "u_component_of_wind",
            "v_component_of_wind"
        ],
        "pressure_level": "850",
        "year": year_str,
        "month": months,
        "day": [f"{d:02d}" for d in range(1, 32)],
        "daily_statistic": "daily_mean",
        "time_zone": "utc+00:00",
        "frequency": "1_hourly",
        "data_format": "netcdf",
        "area": area
    }

    c.retrieve(
        "derived-era5-pressure-levels-daily-statistics",
        request,
        out_file
    )

# =====================================================
# MERGE ALL FILES
# =====================================================

print("\n📦 Opening datasets...")

ds_single = xr.open_mfdataset(single_files, combine="by_coords")
ds_pl = xr.open_mfdataset(pl_files, combine="by_coords")

print("🔗 Merging datasets...")

ds = xr.merge([ds_single, ds_pl])

print("💾 Saving final file...")

ds.to_netcdf(final_file)

print("\n✅ DONE — Final merged file saved:")
print(final_file)
# Out:
# ⬇ Downloading single level: 2019
# 2026-02-24 13:26:46,453 INFO Request ID is 93073d39-ed02-4566-95a3-e590b029df5f
# 2026-02-24 13:26:46,670 INFO status has been updated to accepted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 61
#      41     print("⬇ Downloading single level:", year_str)
#      43     request = {
#      44         "product_type": "reanalysis",
#      45         "variable": [
#    (...)     58         "area": area
#      59     }
# ---> 61     c.retrieve(
#      62         "derived-era5-single-levels-daily-statistics",
#      63         request,
#      64         out_file
#      65     )
#      67 # =====================================================
#      68 # DOWNLOAD PRESSURE LEVEL DATA
#      69 # =====================================================
#      71 pl_files = []
#
# ...

# %%
import xarray as xr

file_path = "/media/nilay/HDD/IIT KGP 2025/PHD/VS CODES/total_precipitation_stream-oper_daily-mean.nc"

ds = xr.open_dataset(file_path, engine="netcdf4")

print(ds)
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (valid_time: 31, latitude: 201, longitude: 161)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 248B 1985-10-01 ... 1985-10-31
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 1kB 60.0 60.25 60.5 ... 99.5 99.75 100.0
#     number      int64 8B ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-02-23T08:39 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
import xarray as xr

file_path = "/media/nilay/HDD/IIT KGP 2025/PHD/VS CODES/total_precipitation_stream-oper_daily-mean.nc"

ds = xr.open_dataset(file_path)

# Print full dataset summary
print(ds)

# Print variables (columns)
print("\nVariables:")
print(list(ds.data_vars))
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (valid_time: 31, latitude: 201, longitude: 161)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 248B 1985-10-01 ... 1985-10-31
#   * latitude    (latitude) float64 2kB 50.0 49.75 49.5 49.25 ... 0.5 0.25 0.0
#   * longitude   (longitude) float64 1kB 60.0 60.25 60.5 ... 99.5 99.75 100.0
#     number      int64 8B ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-02-23T08:39 GRIB to CDM+CF via cfgrib-0.9.1...
#
# Variables:
# ['tp']
